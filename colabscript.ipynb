# %% [markdown]
# <a href="https://colab.research.google.com/github/henrykohl/deeplearningproject/blob/main/colabscript.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * 安裝 conda on Colab

# %%
# !pip install -q condacolab
import condacolab
condacolab.install() # expect a kernel restart
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %% [markdown]
# - Clone Repository

# %%
# !git clone https://github.com/henrykohl/deeplearningproject.git
# Out:
# Cloning into 'deeplearningproject'...
# remote: Enumerating objects: 184, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 184 (delta 95), reused 126 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (184/184), 1.02 MiB | 4.43 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %% [markdown]
# - 切換 workspace

# %%
# %cd deeplearningproject/
# Out:
# /content/deeplearningproject

# %% [markdown]
# - 建立 environment

# %%
# !conda create -p env python=3.8 -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /content/deeplearningproject/env
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.1.31  |       hbcca054_0         154 KB  conda-forge
#     ld_impl_linux-64-2.43      |       h712a8e2_4         656 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_0          52 KB  conda-forge
#     libgcc-14.2.0              |       h767d61c_2         828 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_2          52 KB  conda-forge
# ...

# %% [markdown]
# * (啟動 env) 安裝 requirement_dev packages

# %%
# !source activate ./env; pip install -r requirements.txt
# Out:
# Obtaining file:///content/deeplearningproject (from -r requirements.txt (line 7))
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 29.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 158.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 51.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 84.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.5/746.5 kB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# * 檢查當下 workspace

# %%
# !pwd
# Out:
# /content/deeplearningproject

# %% [markdown]
# * (啟動 env) 檢查當下環境已安裝的 packages

# %%
# !source activate ./env; pip3 list

# %% [markdown]
# * (啟動 env) 安裝 aws configure

# %%
# !source activate ./env; pip install aws configure --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 79.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 41.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# * (啟動 env) 安裝 aws awscli

# %%
# !source activate ./env; pip install awscli --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 39.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 23.2 MB/s eta 0:00:00

# %% [markdown]
# * (啟動 env) 測試 aws configuration

# %%
# !source activate ./env; aws configuration
# Out:
# Note: AWS CLI version 2, the latest major version of the AWS CLI, is now stable and recommended for general use. For more information, see the AWS CLI version 2 installation instructions at: https://docs.aws.amazon.com/cli/latest/userguide/install-cliv2.html
#
# usage: aws [options] <command> <subcommand> [<subcommand> ...] [parameters]
# To see help text, you can run:
#
#   aws help
#   aws <command> help
#   aws <command> <subcommand> help
# aws: error: argument command: Invalid choice, valid choices are:
#
# accessanalyzer                           | account
# acm                                      | acm-pca
# amp                                      | amplify
# amplifybackend                           | amplifyuibuilder
# apigateway                               | apigatewaymanagementapi
# apigatewayv2                             | appconfig
# appconfigdata                            | appfabric
# appflow                                  | appintegrations
# ...

# %%
# !source activate ./env; aws configure
# Out:
# AWS Access Key ID [None]: AKIA4MTWN7L7ZKT7MBA2
# AWS Secret Access Key [None]: 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
# Default region name [None]: us-east-1
# Default output format [None]:

# %% [markdown]
# * (啟動 env) 運行 Data Ingestion
# > 執行  /content/deeplearningproject/Xray/pipeline/training_pipeline.py

# %%
# !source activate ./env; python -m Xray.pipeline.training_pipeline
# Out:
# download: s3://xraylungimgsproj/data/test/NORMAL/IM-0001-0001.jpeg to artifacts/03_20_2025_18_00_04/data_ingestion/data/test/NORMAL/IM-0001-0001.jpeg
# download: s3://xraylungimgsproj/data/test/NORMAL/IM-0006-0001.jpeg to artifacts/03_20_2025_18_00_04/data_ingestion/data/test/NORMAL/IM-0006-0001.jpeg
# download: s3://xraylungimgsproj/data/test/NORMAL/IM-0003-0001.jpeg to artifacts/03_20_2025_18_00_04/data_ingestion/data/test/NORMAL/IM-0003-0001.jpeg
# download: s3://xraylungimgsproj/data/test/NORMAL/IM-0013-0001.jpeg to artifacts/03_20_2025_18_00_04/data_ingestion/data/test/NORMAL/IM-0013-0001.jpeg
# download: s3://xraylungimgsproj/data/test/NORMAL/IM-0011-0001.jpeg to artifacts/03_20_2025_18_00_04/data_ingestion/data/test/NORMAL/IM-0011-0001.jpeg
# download: s3://xraylungimgsproj/data/test/NORMAL/IM-0011-0001-0002.jpeg to artifacts/03_20_2025_18_00_04/data_ingestion/data/test/NORMAL/IM-0011-0001-0002.jpeg
# ...

# %% [markdown]
# * (啟動 env) 運行 Data Ingestion + Data Transformation
# > 執行  /content/deeplearningproject/main.py

# %%
# !source activate ./env; python main.py
